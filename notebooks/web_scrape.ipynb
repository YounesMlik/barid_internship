# %%
# %cd "c:\Users\user\Desktop\younes\data_exploration\uv_project"
# Out:
# c:\Users\user\Desktop\younes\data_exploration\uv_project

# %%
rows = [
    ["48988622", "QB126495227MA", "0.1", "VALIDE (V)", "liv", "517", "Détail"],
    ["49043932", "QB126495227MA", "0.0", "VALIDE (V)", "liv", "POD", "Détail"],
]
rows

# %%
import main
import lib
import importlib

importlib.reload(lib)
importlib.reload(main)

data = lib.read_smi_suiviexpedition_many()

# %%
data.filter(CAB="QD127960211MA")
# Out:
# shape: (1, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ CAB       ┆ CLIENT    ┆ SERVICES_ ┆ SITE_EXPE ┆ … ┆ DERNIER_S ┆ DATE_DERN ┆ SITE_DERN ┆ DESTINAT │
# │ ---       ┆ ---       ┆ OPTIONNEL ┆ DITEUR    ┆   ┆ TATUT     ┆ IER_STATU ┆ IER_STATU ┆ ION      │
# │ str       ┆ str       ┆ S         ┆ ---       ┆   ┆ ---       ┆ T         ┆ T         ┆ ---      │
# │           ┆           ┆ ---       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆ str      │
# │           ┆           ┆ str       ┆           ┆   ┆           ┆ datetime[ ┆ str       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ μs]       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ QD1279602 ┆ SOREC -   ┆ -         ┆ CENTRE    ┆ … ┆ liv       ┆ 2024-12-1 ┆ CENTRE    ┆ LAAYOUNE │
# ...
