# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path(sys.prefix).parent
# %cd {PROJECT_ROOT}
# Out:
# /home/younes/younes/Projects/Python/barid_internship

# %%
import polars as pl

# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import statsmodels.api as sm
# from statsmodels.graphics.tsaplots import plot_acf
# import calendar
# from fpppy.utils import plot_series, plot_series_stacked, plot_diagnostics
# from scipy.stats import pearsonr
# from plotly import express as px
# import altair as alt
from pathlib import Path
from lxml import html
from itertools import chain

import importlib
import offline_historique

importlib.reload(offline_historique)
from offline_historique import parse_historique_from_folder  # noqa: E402

cfg = pl.Config()
cfg.set_tbl_width_chars(10000)
cfg.set_fmt_str_lengths(30)
cfg.set_tbl_cols(-1)
cfg.set_tbl_rows(10)
# Out:
# polars.config.Config

# %%
parse_historique_from_folder("data/cab/", "data/cab_dfs/", save_output=False)
# Out:
# {'delivery': shape: (103_846, 13)
#  ┌──────────────────────┬──────────┬────────────────────────────────┬────────────┬─────────────────┬─────────┬─────────────────┬───────┬──────────────────────┬─────────────────┬──────┬────────────────┬─────────────────────────────────┐
#  │ cab                  ┆ id       ┆ agence_liv                     ┆ date_liv   ┆ date_transf_ccp ┆ montant ┆ beneficiaire    ┆ n_pid ┆ statut               ┆ origine         ┆ etat ┆ N_compte_Infos ┆ N_cheque_N_reçu_TPE             │
#  │ ---                  ┆ ---      ┆ ---                            ┆ ---        ┆ ---             ┆ ---     ┆ ---             ┆ ---   ┆ ---                  ┆ ---             ┆ ---  ┆ ---            ┆ ---                             │
#  │ str                  ┆ str      ┆ str                            ┆ date       ┆ date            ┆ f64     ┆ str             ┆ str   ┆ str                  ┆ str             ┆ str  ┆ str            ┆ str                             │
#  ╞══════════════════════╪══════════╪════════════════════════════════╪════════════╪═════════════════╪═════════╪═════════════════╪═══════╪══════════════════════╪═════════════════╪══════╪════════════════╪═════════════════════════════════╡
#  │ 00340509019212435664 ┆ 59761025 ┆ AGENCE MESSAGERIE LAAYOUNE     ┆ 2024-12-09 ┆ 0001-01-01      ┆ 0.0     ┆ .               ┆ .     ┆ Livraison à 0dhs     ┆ SICOM           ┆ V    ┆ 8508024        ┆ .                               │
#  │ 00340509019212475660 ┆ 59850077 ┆ CENTRE COURRIER COLIS LAAYOUNE ┆ 2024-12-04 ┆ 2024-12-06      ┆ 837.97  ┆ nm              ┆       ┆ TRANSACTION ACCEPTEE ┆ TERMINAL MOBILE ┆ V    ┆ 8508024        ┆ REJET IMPUT.AVANT : SOLDE INSU… │
#  │ 00340509019212480848 ┆ 59899852 ┆ CENTRE COURRIER COLIS LAAYOUNE ┆ 2024-12-09 ┆ 0001-01-01      ┆ 0.0     ┆ nm              ┆       ┆ Livraison à 0dhs     ┆ TERMINAL MOBILE ┆ V    ┆ 8508024        ┆                                 │
#  │ ZG202402336MA        ┆ 59873923 ┆ 2024-12-05     ┆ 2024-12-05 15:45:00 ┆ Livré               ┆ CENTRE COURRIER COLIS LAAYOUNE ┆ 7440011    ┆ [ liv ] VALIDE (V)   ┆           ┆ 0         ┆ AMANA PDA ┆ liv         ┆ V        │
#  └──────────────────────┴──────────┴────────────────┴─────────────────────┴─────────────────────┴────────────────────────────────┴────────────┴──────────────────────┴───────────┴───────────┴───────────┴─────────────┴──────────┘,
#  'services': shape: (85_632, 9)
#  ┌──────────────────────┬──────────┬─────────────────────────────────┬────────────┬─────────────────┬────────────────────┬────────────┬──────────┬─────────┐
#  │ cab                  ┆ id       ┆ Libelle_service                 ┆ Num_compte ┆ Mnt_a_percevoir ┆ Adr/compte service ┆ Gsm        ┆ Taxe_TTC ┆ ORIGINE │
#  │ ---                  ┆ ---      ┆ ---                             ┆ ---        ┆ ---             ┆ ---                ┆ ---        ┆ ---      ┆ ---     │
#  │ str                  ┆ str      ┆ str                             ┆ str        ┆ f64             ┆ str                ┆ str        ┆ f64      ┆ str     │
#  ╞══════════════════════╪══════════╪═════════════════════════════════╪════════════╪═════════════════╪════════════════════╪════════════╪══════════╪═════════╡
#  │ 00340509019212435664 ┆ 59761025 ┆ Notification destinataire par … ┆            ┆ 0.0             ┆                    ┆ 0690290129 ┆ 0.0      ┆ SI COM  │
#  │ 00340509019212435664 ┆ 59761025 ┆ CRBT CCP                        ┆ 8508024    ┆ 0.0             ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  │ 00340509019212435664 ┆ 59761025 ┆ Valeur déclarée                 ┆            ┆ 3930.0          ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  │ 00340509019212475660 ┆ 59850077 ┆ Notification destinataire par … ┆            ┆ 0.0             ┆                    ┆ 0661869114 ┆ 0.0      ┆ SI COM  │
#  │ 00340509019212475660 ┆ 59850077 ┆ CRBT CCP                        ┆ 8508024    ┆ 837.97          ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  │ …                    ┆ …        ┆ …                               ┆ …          ┆ …               ┆ …                  ┆ …          ┆ …        ┆ …       │
#  │ YZ63769471792001MA   ┆ 63764975 ┆ Notification destinataire par … ┆            ┆ 0.0             ┆                    ┆ 0663185465 ┆ 0.0      ┆ SI COM  │
#  │ YZ63769471792001MA   ┆ 63764975 ┆ CRBT CCP                        ┆ 12194543   ┆ 1933.0          ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  │ ZG202402336MA        ┆ 59873923 ┆ Notification destinataire par … ┆            ┆ 0.0             ┆                    ┆ 0662190426 ┆ 0.0      ┆ SI COM  │
#  │ ZG202402336MA        ┆ 59873923 ┆ CRBT CCP                        ┆ 12022722   ┆ 248.0           ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  │ ZG202402336MA        ┆ 59873923 ┆ Valeur déclarée                 ┆            ┆ 500.0           ┆                    ┆            ┆ 0.0      ┆ SI COM  │
#  └──────────────────────┴──────────┴─────────────────────────────────┴────────────┴─────────────────┴────────────────────┴────────────┴──────────┴─────────┘,
#  'fields': shape: (111_060, 21)
#  ┌──────────────────────┬──────────┬────────────┬──────────┬────────────────┬────────┬─────────┬──────────────────┬────────────────────┬─────────────────────────────────┬─────────────┬─────────────────────────────────┬────────────────────────┬─────────────────────────────────┬──────────────┬──────────────────────┬──────────────────────┬──────────┬─────────┬─────────┬────────────────────┐
#  │ Cab                  ┆ Id       ┆ Date_depot ┆ Type_cab ┆ Dernier_statut ┆ Regime ┆ Contrat ┆ Etat             ┆ Poids_global_en_KG ┆ Centre_Agence_depot             ┆ Destination ┆ Client                          ┆ Produit_Niveau_Service ┆ Mode_paiement                   ┆ Taxe_DTQ_Dhs ┆ Canal_de_livraison_1 ┆ Canal_de_livraison_2 ┆ Longueur ┆ Hauteur ┆ Largeur ┆ Poids_Volumetrique │
#  │ ---                  ┆ ---      ┆ ---        ┆ ---      ┆ ---            ┆ ---    ┆ ---     ┆ ---              ┆ ---                ┆ ---                             ┆ ---         ┆ ---                             ┆ ---                    ┆ ---                             ┆ ---          ┆ ---                  ┆ ---                  ┆ ---      ┆ ---     ┆ ---     ┆ ---                │
#  │ str                  ┆ i64      ┆ date       ┆ i64      ┆ str            ┆ str    ┆ i64     ┆ str              ┆ f64                ┆ str                             ┆ str         ┆ str                             ┆ str                    ┆ str                             ┆ f64          ┆ str                  ┆ str                  ┆ f64      ┆ f64     ┆ f64     ┆ f64                │
#  ╞══════════════════════╪══════════╪════════════╪══════════╪════════════════╪════════╪═════════╪══════════════════╪════════════════════╪═════════════════════════════════╪═════════════╪═════════════════════════════════╪════════════════════════╪═════════════════════════════════╪══════════════╪══════════════════════╪══════════════════════╪══════════╪═════════╪═════════╪════════════════════╡
#  │ 00340509019212435664 ┆ 59761025 ┆ 2024-11-26 ┆ 99       ┆ liv            ┆ NAT    ┆ 2289    ┆ V                ┆ 7.9                ┆ CENTRE NATIONAL AMANA(96351)    ┆ LAAYOUNE    ┆ FOREVER LIVING PRODUCTS MAROC(… ┆ Amana Express 3        ┆ Paiement CEC en différé , ou ,… ┆ 0.0          ┆                      ┆                      ┆ null     ┆ null    ┆ null    ┆ 0.0                │
#  │ 00340509019212475660 ┆ 59850077 ┆ 2024-12-02 ┆ 99       ┆ liv            ┆ NAT    ┆ 2289    ┆ V                ┆ 3.075              ┆ CENTRE NATIONAL AMANA(96351)    ┆ LAAYOUNE    ┆ FOREVER LIVING PRODUCTS MAROC(… ┆ Amana Express 3        ┆ Paiement CEC en différé , ou ,… ┆ 0.0          ┆                      ┆                      ┆ null     ┆ null    ┆ null    ┆ 0.0                │
#  │ 00340509019212480848 ┆ 59899852 ┆ 2024-12-04 ┆ 99       ┆ liv            ┆ NAT    ┆ 2289    ┆ V                ┆ 1.54               ┆ CENTRE NATIONAL AMANA(96351)    ┆ LAAYOUNE    ┆ FOREVER LIVING PRODUCTS MAROC(… ┆ Amana Express 3        ┆ Paiement CEC en différé , ou ,… ┆ 0.0          ┆                      ┆                      ┆ null     ┆ null    ┆ null    ┆ 0.0                │
#  │ ZG202402336MA        ┆ 59873923 ┆ 2024-12-03 ┆ 99       ┆ liv            ┆ NAT    ┆ 18314   ┆ V                ┆ 5.0                ┆ CENTRE MESSAGERIE MEKNES(96349… ┆ LAAYOUNE    ┆ SOCIETE ZAK-GIO(4000019449.0)   ┆ Amana Express 3        ┆ Paiement CEC en différé , ou ,… ┆ 0.0          ┆                      ┆                      ┆ null     ┆ null    ┆ null    ┆ 0.0                │
#  └──────────────────────┴──────────┴────────────┴──────────┴────────────────┴────────┴─────────┴──────────────────┴────────────────────┴─────────────────────────────────┴─────────────┴─────────────────────────────────┴────────────────────────┴─────────────────────────────────┴──────────────┴──────────────────────┴──────────────────────┴──────────┴─────────┴─────────┴────────────────────┘}

# %%
# import cProfile
# import pstats

# profiler = cProfile.Profile()

# profiler.enable()

# parse_historique_from_folder("data/cab/", "data/cab_dfs/", save_output=False)

# profiler.disable()

# stats = pstats.Stats(profiler)
# stats.sort_stats("cumtime").print_stats(40)
# Out:
#          2435078 function calls (2435071 primitive calls) in 6.008 seconds
#
#    Ordered by: cumulative time
#    List reduced from 248 to 40 due to restriction <40>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    6.004    3.002 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3712(run_code)
#         2    0.000    0.000    6.004    3.002 {built-in method builtins.exec}
#         1    0.231    0.231    5.998    5.998 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:219(extract_pages)
#      1000    0.089    0.000    5.288    0.005 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:208(extract_page)
#      3000    0.024    0.000    2.070    0.001 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:154(extract_table)
#      1000    0.966    0.001    1.846    0.002 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:177(extract_fields)
#      1000    0.011    0.000    1.285    0.001 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/lxml/html/__init__.py:839(fromstring)
#      1000    1.257    0.001    1.266    0.001 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/lxml/html/__init__.py:737(document_fromstring)
#      3000    1.251    0.000    1.265    0.000 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/lxml/html/__init__.py:375(get_element_by_id)
#    707835    0.598    0.000    1.016    0.000 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/lxml/html/__init__.py:714(lookup)
#      2436    0.237    0.000    0.781    0.000 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:149(parse_table_rows)
#      1001    0.004    0.000    0.428    0.000 /tmp/ipykernel_8046/1782293030.py:8(<genexpr>)
#      1000    0.007    0.000    0.424    0.000 /home/younes/anaconda3/lib/python3.13/pathlib/_local.py:539(read_text)
#      1000    0.008    0.000    0.416    0.000 /home/younes/anaconda3/lib/python3.13/pathlib/_abc.py:628(read_text)
#    108922    0.338    0.000    0.338    0.000 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/lxml/html/__init__.py:396(text_content)
#      1000    0.002    0.000    0.286    0.000 /home/younes/anaconda3/lib/python3.13/pathlib/_local.py:529(open)
#      1000    0.276    0.000    0.284    0.000 {built-in method _io.open}
#    727959    0.227    0.000    0.227    0.000 {method 'get' of 'dict' objects}
#    706891    0.199    0.000    0.199    0.000 {method 'lower' of 'str' objects}
#      1000    0.092    0.000    0.110    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#    124723    0.056    0.000    0.056    0.000 {method 'strip' of 'str' objects}
#     19552    0.027    0.000    0.027    0.000 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:145(<lambda>)
#       7/4    0.000    0.000    0.026    0.006 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/dataframe/frame.py:374(__init__)
#       944    0.002    0.000    0.024    0.000 /home/younes/younes/Projects/Python/barid_internship/offline_historique.py:144(<lambda>)
#         4    0.000    0.000    0.024    0.006 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/_utils/construction/dataframe.py:443(sequence_to_pydf)
#         4    0.000    0.000    0.024    0.006 /home/younes/anaconda3/lib/python3.13/functools.py:930(wrapper)
#         3    0.002    0.001    0.021    0.007 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/_utils/construction/dataframe.py:961(iterable_to_pydf)
#         3    0.000    0.000    0.019    0.006 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/_utils/construction/dataframe.py:1004(to_frame_chunk)
#         3    0.000    0.000    0.019    0.006 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/_utils/construction/dataframe.py:536(_sequence_of_sequence_to_pydf)
#         3    0.019    0.006    0.019    0.006 {built-in method from_rows}
#      1000    0.004    0.000    0.018    0.000 <frozen codecs>:322(decode)
#      1000    0.014    0.000    0.014    0.000 {built-in method _codecs.utf_8_decode}
#      1000    0.011    0.000    0.011    0.000 {method '__exit__' of '_io._IOBase' objects}
#         4    0.000    0.000    0.009    0.002 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/dataframe/frame.py:10383(with_columns)
#         7    0.000    0.000    0.009    0.001 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/_utils/deprecation.py:84(wrapper)
#         7    0.000    0.000    0.009    0.001 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/lazyframe/opt_flags.py:327(wrapper)
#         7    0.000    0.000    0.008    0.001 /home/younes/younes/Projects/Python/barid_internship/.venv/lib/python3.13/site-packages/polars/lazyframe/frame.py:2279(collect)
#         7    0.008    0.001    0.008    0.001 {method 'collect' of 'builtins.PyLazyFrame' objects}
#         4    0.000    0.000    0.008    0.002 /home/younes/anaconda3/lib/python3.13/asyncio/events.py:87(_run)
#         4    0.000    0.000    0.008    0.002 {method 'run' of '_contextvars.Context' objects}
